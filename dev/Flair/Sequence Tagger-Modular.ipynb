# %% [markdown]
# # State of the art NER using Flair Sequence Tagger
# See SoTA Experimental setups: https://github.com/flairNLP/flair/blob/master/resources/docs/EXPERIMENTS.md

# %%
import os
from itertools import groupby
import itertools
import random
import numpy as np
import math
import json

# %%
import flair, torch
flair.device = torch.device('cuda:0')

# %%
from flair.data import Corpus
from flair.datasets import CONLL_03
from flair.embeddings import TokenEmbeddings, WordEmbeddings, StackedEmbeddings, PooledFlairEmbeddings
from typing import List
from flair.models import SequenceTagger

from flair.trainers import ModelTrainer
from datetime import datetime

# %% [markdown]
# ### Data Preparation
# 1. Join train, dev, test into single dataset for k-fold cross-validation
# 2. Create splits with given sizes

# %% [markdown]
# For each partition of data with `k` samples, we split the dataset into three sets with the following distribution: `80/10/10` for the train, dev, and test set, respectively. Therefore, for each `k` there will be varying sizes of all three sets of data, however this makes more intuitive sense than only partitioning the test set and keeping the dev and test sets the same size as if they were at `k_n`.

# %% [markdown]
# `DOCTSTART` has been removed from these documents as it's not required for model learning

# %%
def run_seqtag_model(train_split: float, dev_split: float = 1.0, train_w_dev: bool = False, max_epochs: int = 50, runs: int = 5):
    
    for run in range(1, runs+1,1):
        
        # run save path is used to save run data and results
        run_save_path = os.getcwd() + f'/runs/{str(int(train_split*100))}/{run}/'
        
        
        # Prepare data and write to disk
        data_path = os.getcwd() + '/resources/tasks/conll_03/full data/'

        # Name: Number of documents
        # Sample counts DO NOT include DOCSTARTs 
        splits = {'train': {'len': 14041, 'samples': []}, 'dev': {'len': 3250, 'samples': []}, 'test': {'len': 3453, 'samples': []}}
        
        all_data = []
        for split_name in splits:
            print(f'Processing: {split_name}')

            with open(data_path + split_name + '.txt', 'r') as fr:
                lines = fr.readlines()
            
            # Remove doc separator
            # TODO: make more abstract, DOCSTART in CONLL2003 specific
            lines = [line for line in lines if '-DOCSTART-' not in line]
            
            # Groups documents based on position of new line separators (lines with no tokens)
            docs = [list(group) for k, group in groupby(lines, lambda x: len(x) == 1) if not k]
            
            print(f'Dataset size (docs): {len(docs)}')

            all_data.append(docs)

        # Currently using oversized dev/test sets relative to small sample sizes at the beginning of training splits (e.g. 3k for test/dev and %*train_len)
        all_data = np.array(list(itertools.chain(*all_data)))
        dataset_size = len(all_data)
        all_indices = set(np.arange(dataset_size))

        for split_name in splits:
            if split_name == 'test':
                # Use entire 3k of test samples
                sampled_indices = np.array(random.sample(list(all_indices), k=splits[split_name]['len']))

            if split_name == 'dev':
                # Split dev set with the same proportion of it's original dataset ~24% of the training split
                sampled_indices = np.array(random.sample(list(all_indices), k=math.ceil(splits[split_name]['len']*dev_split)))

            if split_name == 'train':
                sampled_indices = np.array(random.sample(list(all_indices), k=math.ceil(splits[split_name]['len']*train_split)))
            splits[split_name]['samples'] = sampled_indices
            # Remove sampled indices from dataset
            all_indices = np.setdiff1d(list(all_indices), sampled_indices)

        print(f'Size of datasets: Train {len(splits["train"]["samples"])} Dev {len(splits["dev"]["samples"])} Test {len(splits["test"]["samples"])}')
        print(f'Train Sample\n{all_data[splits["train"]["samples"][0]]}\nDev Sample\n{all_data[splits["dev"]["samples"][0]]}')
        
        try:
            if os.path.exists(os.path.join(run_save_path, 'conll_03')):
                pass
            else:
                os.mkdir(os.path.join(run_save_path, 'conll_03'))
        except:
            print('Failure to make conll_03 folder')
        
        # Save splits back into directory for Corpus reader to find
        for split_name in splits:
            print(split_name)
            split_data_str = "\n".join(["".join(doc) for doc in all_data[splits[split_name]['samples']]])
            with open(os.getcwd() + '/resources/tasks/conll_03/' + split_name + '.txt', 'w') as fw:
                fw.write(split_data_str)
                fw.close()
            
            # Save a copy to run folder
            with open(run_save_path + 'conll_03/' + split_name + '.txt', 'w') as fw:
                fw.write(split_data_str)
                fw.close()

        # Flair Model Initialisation and Training
        # 1. get the corpus
        corpus: Corpus = CONLL_03(base_path=run_save_path)
        # 2. what tag do we want to predict?
        tag_type = 'ner'
        # 3. make the tag dictionary from the corpus
        tag_dictionary = corpus.make_tag_dictionary(tag_type=tag_type)
        
        print(tag_dictionary)

        # initialize embeddings
        embedding_types: List[TokenEmbeddings] = [

            # GloVe embeddings
            WordEmbeddings('glove'),

            # contextual string embeddings, forward
            PooledFlairEmbeddings('news-forward', pooling='min'),

            # contextual string embeddings, backward
            PooledFlairEmbeddings('news-backward', pooling='min'),
        ]

        embeddings: StackedEmbeddings = StackedEmbeddings(embeddings=embedding_types)

        # initialize sequence tagger
        tagger: SequenceTagger = SequenceTagger(hidden_size=256,
                                                embeddings=embeddings,
                                                tag_dictionary=tag_dictionary,
                                                tag_type=tag_type)

        # initialize trainer
        trainer: ModelTrainer = ModelTrainer(tagger, corpus)

        save_path = f'resources/taggers/example-ner-{train_split*100:0.0f} ' + 'twd0' if train_w_dev else 'twd1'
        results = trainer.train(save_path,
                                train_with_dev=train_w_dev,
                                max_epochs=max_epochs)   # 150
        
        # Save results to run file
        with open(run_save_path + 'results.json', 'w') as fwj:
            json.dump(results, fwj)
    
    return results

# %%
splits_to_run = [0.1]
[run_seqtag_model(train_split=split, max_epochs=50, runs=5) for split in splits_to_run]
# Out:
# Processing: train
# Dataset size (docs): 14041
# Processing: dev
# Dataset size (docs): 3250
# Processing: test
# Dataset size (docs): 3453
# Size of datasets: Train 1405 Dev 3250 Test 3453
# Train Sample
# ['Total JJ B-NP O\n', '( ( O O\n', 'for IN B-PP O\n', 'one CD B-NP O\n', 'wicket NN I-NP O\n', ') ) O O\n', '48 CD B-NP O\n']
# Dev Sample
# ['Attendence NN B-NP O\n', ': : O O\n', '200 CD B-NP O\n']
# train
# dev
# test
# 2020-12-08 05:52:40,720 Reading data from /home/tyler/Desktop/Repos/s-vaal/dev/Flair/runs/10/1/conll_03
# 2020-12-08 05:52:40,721 Train: /home/tyler/Desktop/Repos/s-vaal/dev/Flair/runs/10/1/conll_03/train.txt
# 2020-12-08 05:52:40,722 Dev: /home/tyler/Desktop/Repos/s-vaal/dev/Flair/runs/10/1/conll_03/dev.txt
# 2020-12-08 05:52:40,722 Test: /home/tyler/Desktop/Repos/s-vaal/dev/Flair/runs/10/1/conll_03/test.txt
# <ipython-input-4-64947fc477ea>:35: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   all_data = np.array(list(itertools.chain(*all_data)))
# Dictionary with 20 tags: <unk>, O, S-LOC, S-ORG, B-PER, E-PER, B-ORG, E-ORG, S-MISC, B-MISC, E-MISC, I-ORG, B-LOC, E-LOC, S-PER, I-MISC, I-LOC, I-PER, <START>, <STOP>
# 2020-12-08 05:52:50,348 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:52:50,348 Model: "SequenceTagger(
#   (embeddings): StackedEmbeddings(
#     (list_embedding_0): WordEmbeddings('glove')
#     (list_embedding_1): PooledFlairEmbeddings(
#       (context_embeddings): FlairEmbeddings(
#         (lm): LanguageModel(
#           (drop): Dropout(p=0.05, inplace=False)
#           (encoder): Embedding(300, 100)
#           (rnn): LSTM(100, 2048)
#           (decoder): Linear(in_features=2048, out_features=300, bias=True)
#         )
#       )
#     )
#     (list_embedding_2): PooledFlairEmbeddings(
#       (context_embeddings): FlairEmbeddings(
#         (lm): LanguageModel(
#           (drop): Dropout(p=0.05, inplace=False)
#           (encoder): Embedding(300, 100)
#           (rnn): LSTM(100, 2048)
#           (decoder): Linear(in_features=2048, out_features=300, bias=True)
#         )
#       )
#     )
#   )
#   (word_dropout): WordDropout(p=0.05)
#   (locked_dropout): LockedDropout(p=0.5)
#   (embedding2nn): Linear(in_features=8292, out_features=8292, bias=True)
#   (rnn): LSTM(8292, 256, batch_first=True, bidirectional=True)
#   (linear): Linear(in_features=512, out_features=20, bias=True)
#   (beta): 1.0
#   (weights): None
#   (weight_tensor) None
# )"
# 2020-12-08 05:52:50,349 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:52:50,350 Corpus: "Corpus: 1405 train + 3250 dev + 3453 test sentences"
# 2020-12-08 05:52:50,350 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:52:50,351 Parameters:
# 2020-12-08 05:52:50,352  - learning_rate: "0.1"
# 2020-12-08 05:52:50,352  - mini_batch_size: "32"
# 2020-12-08 05:52:50,353  - patience: "3"
# 2020-12-08 05:52:50,353  - anneal_factor: "0.5"
# 2020-12-08 05:52:50,354  - max_epochs: "50"
# 2020-12-08 05:52:50,355  - shuffle: "True"
# 2020-12-08 05:52:50,355  - train_with_dev: "False"
# 2020-12-08 05:52:50,356  - batch_growth_annealing: "False"
# 2020-12-08 05:52:50,357 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:52:50,357 Model training base path: "twd1"
# 2020-12-08 05:52:50,358 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:52:50,359 Device: cuda:0
# 2020-12-08 05:52:50,360 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:52:50,374 Embeddings storage mode: cpu
# 2020-12-08 05:52:50,376 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 05:52:52,712 epoch 1 - iter 4/44 - loss 22.87972379 - samples/sec: 54.81 - lr: 0.100000
# 2020-12-08 05:52:54,763 epoch 1 - iter 8/44 - loss 17.87661457 - samples/sec: 62.45 - lr: 0.100000
# 2020-12-08 05:52:56,980 epoch 1 - iter 12/44 - loss 15.86121798 - samples/sec: 57.76 - lr: 0.100000
# 2020-12-08 05:52:59,199 epoch 1 - iter 16/44 - loss 14.50090879 - samples/sec: 57.70 - lr: 0.100000
# 2020-12-08 05:53:01,796 epoch 1 - iter 20/44 - loss 13.97759347 - samples/sec: 49.31 - lr: 0.100000
# 2020-12-08 05:53:03,853 epoch 1 - iter 24/44 - loss 13.17053346 - samples/sec: 62.26 - lr: 0.100000
# 2020-12-08 05:53:06,611 epoch 1 - iter 28/44 - loss 12.31743947 - samples/sec: 46.42 - lr: 0.100000
# 2020-12-08 05:53:08,994 epoch 1 - iter 32/44 - loss 11.80076979 - samples/sec: 53.75 - lr: 0.100000
# 2020-12-08 05:53:11,267 epoch 1 - iter 36/44 - loss 11.21070328 - samples/sec: 56.32 - lr: 0.100000
# 2020-12-08 05:53:13,608 epoch 1 - iter 40/44 - loss 10.70670740 - samples/sec: 54.71 - lr: 0.100000
# 2020-12-08 05:53:16,016 epoch 1 - iter 44/44 - loss 10.27352538 - samples/sec: 53.17 - lr: 0.100000
# 2020-12-08 05:53:16,017 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:53:16,017 EPOCH 1 done: loss 10.2735 - lr 0.1000000
# 2020-12-08 05:54:03,819 DEV : loss 4.60466194152832 - score 0.6088
# 2020-12-08 05:54:04,077 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 05:54:10,629 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 05:54:11,799 epoch 2 - iter 4/44 - loss 4.94604605 - samples/sec: 115.99 - lr: 0.100000
# 2020-12-08 05:54:12,919 epoch 2 - iter 8/44 - loss 5.24682853 - samples/sec: 114.39 - lr: 0.100000
# 2020-12-08 05:54:13,958 epoch 2 - iter 12/44 - loss 4.97567985 - samples/sec: 123.42 - lr: 0.100000
# 2020-12-08 05:54:14,984 epoch 2 - iter 16/44 - loss 4.94427706 - samples/sec: 124.94 - lr: 0.100000
# 2020-12-08 05:54:16,143 epoch 2 - iter 20/44 - loss 4.91576682 - samples/sec: 110.50 - lr: 0.100000
# 2020-12-08 05:54:17,167 epoch 2 - iter 24/44 - loss 4.78411777 - samples/sec: 125.12 - lr: 0.100000
# 2020-12-08 05:54:18,255 epoch 2 - iter 28/44 - loss 4.68574178 - samples/sec: 117.73 - lr: 0.100000
# 2020-12-08 05:54:19,317 epoch 2 - iter 32/44 - loss 4.55973631 - samples/sec: 120.63 - lr: 0.100000
# 2020-12-08 05:54:20,397 epoch 2 - iter 36/44 - loss 4.57441231 - samples/sec: 118.65 - lr: 0.100000
# 2020-12-08 05:54:21,430 epoch 2 - iter 40/44 - loss 4.41782485 - samples/sec: 124.01 - lr: 0.100000
# 2020-12-08 05:54:22,561 epoch 2 - iter 44/44 - loss 4.36730607 - samples/sec: 113.31 - lr: 0.100000
# 2020-12-08 05:54:22,561 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:54:22,562 EPOCH 2 done: loss 4.3673 - lr 0.1000000
# 2020-12-08 05:54:37,546 DEV : loss 2.5257132053375244 - score 0.7651
# 2020-12-08 05:54:37,801 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 05:54:44,462 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 05:54:45,543 epoch 3 - iter 4/44 - loss 3.54554850 - samples/sec: 119.15 - lr: 0.100000
# 2020-12-08 05:54:47,356 epoch 3 - iter 8/44 - loss 3.21758315 - samples/sec: 70.61 - lr: 0.100000
# 2020-12-08 05:54:48,420 epoch 3 - iter 12/44 - loss 3.28076436 - samples/sec: 120.41 - lr: 0.100000
# 2020-12-08 05:54:49,542 epoch 3 - iter 16/44 - loss 3.22186662 - samples/sec: 114.22 - lr: 0.100000
# 2020-12-08 05:54:50,603 epoch 3 - iter 20/44 - loss 3.20134376 - samples/sec: 120.87 - lr: 0.100000
# 2020-12-08 05:54:51,692 epoch 3 - iter 24/44 - loss 3.12728470 - samples/sec: 117.59 - lr: 0.100000
# 2020-12-08 05:54:52,982 epoch 3 - iter 28/44 - loss 3.07878844 - samples/sec: 99.28 - lr: 0.100000
# 2020-12-08 05:54:54,157 epoch 3 - iter 32/44 - loss 3.03063117 - samples/sec: 109.12 - lr: 0.100000
# 2020-12-08 05:54:55,247 epoch 3 - iter 36/44 - loss 3.01317052 - samples/sec: 117.52 - lr: 0.100000
# 2020-12-08 05:54:56,178 epoch 3 - iter 40/44 - loss 2.88399557 - samples/sec: 137.68 - lr: 0.100000
# 2020-12-08 05:54:57,298 epoch 3 - iter 44/44 - loss 2.91359312 - samples/sec: 114.35 - lr: 0.100000
# 2020-12-08 05:54:57,300 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:54:57,300 EPOCH 3 done: loss 2.9136 - lr 0.1000000
# 2020-12-08 05:55:12,085 DEV : loss 2.035123825073242 - score 0.8116
# 2020-12-08 05:55:12,350 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 05:55:19,142 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 05:55:20,308 epoch 4 - iter 4/44 - loss 2.20397350 - samples/sec: 110.14 - lr: 0.100000
# 2020-12-08 05:55:21,301 epoch 4 - iter 8/44 - loss 2.10504974 - samples/sec: 128.95 - lr: 0.100000
# 2020-12-08 05:55:22,361 epoch 4 - iter 12/44 - loss 2.10209901 - samples/sec: 120.89 - lr: 0.100000
# 2020-12-08 05:55:23,385 epoch 4 - iter 16/44 - loss 2.13366864 - samples/sec: 125.14 - lr: 0.100000
# 2020-12-08 05:55:24,568 epoch 4 - iter 20/44 - loss 2.17149517 - samples/sec: 108.30 - lr: 0.100000
# 2020-12-08 05:55:25,668 epoch 4 - iter 24/44 - loss 2.26303931 - samples/sec: 116.42 - lr: 0.100000
# 2020-12-08 05:55:26,877 epoch 4 - iter 28/44 - loss 2.27527170 - samples/sec: 105.96 - lr: 0.100000
# 2020-12-08 05:55:27,970 epoch 4 - iter 32/44 - loss 2.26557631 - samples/sec: 117.21 - lr: 0.100000
# 2020-12-08 05:55:29,100 epoch 4 - iter 36/44 - loss 2.28623893 - samples/sec: 113.39 - lr: 0.100000
# 2020-12-08 05:55:30,223 epoch 4 - iter 40/44 - loss 2.36088253 - samples/sec: 114.02 - lr: 0.100000
# 2020-12-08 05:55:31,348 epoch 4 - iter 44/44 - loss 2.36731024 - samples/sec: 113.85 - lr: 0.100000
# 2020-12-08 05:55:31,349 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:55:31,350 EPOCH 4 done: loss 2.3673 - lr 0.1000000
# 2020-12-08 05:55:46,465 DEV : loss 1.5944855213165283 - score 0.8398
# 2020-12-08 05:55:46,713 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 05:55:54,202 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 05:55:55,370 epoch 5 - iter 4/44 - loss 2.71658939 - samples/sec: 110.36 - lr: 0.100000
# 2020-12-08 05:55:56,541 epoch 5 - iter 8/44 - loss 2.60801691 - samples/sec: 109.46 - lr: 0.100000
# 2020-12-08 05:55:57,744 epoch 5 - iter 12/44 - loss 2.57106994 - samples/sec: 106.43 - lr: 0.100000
# 2020-12-08 05:55:58,774 epoch 5 - iter 16/44 - loss 2.32251028 - samples/sec: 124.44 - lr: 0.100000
# 2020-12-08 05:55:59,827 epoch 5 - iter 20/44 - loss 2.34668866 - samples/sec: 121.66 - lr: 0.100000
# 2020-12-08 05:56:00,920 epoch 5 - iter 24/44 - loss 2.21961950 - samples/sec: 117.14 - lr: 0.100000
# 2020-12-08 05:56:01,988 epoch 5 - iter 28/44 - loss 2.20130554 - samples/sec: 120.00 - lr: 0.100000
# 2020-12-08 05:56:03,095 epoch 5 - iter 32/44 - loss 2.21480830 - samples/sec: 115.72 - lr: 0.100000
# 2020-12-08 05:56:04,100 epoch 5 - iter 36/44 - loss 2.17765254 - samples/sec: 127.46 - lr: 0.100000
# 2020-12-08 05:56:05,165 epoch 5 - iter 40/44 - loss 2.13427283 - samples/sec: 120.37 - lr: 0.100000
# 2020-12-08 05:56:06,251 epoch 5 - iter 44/44 - loss 2.12612520 - samples/sec: 118.01 - lr: 0.100000
# 2020-12-08 05:56:06,251 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:56:06,252 EPOCH 5 done: loss 2.1261 - lr 0.1000000
# 2020-12-08 05:56:21,437 DEV : loss 1.4114413261413574 - score 0.8514
# 2020-12-08 05:56:21,697 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 05:56:28,545 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 05:56:29,745 epoch 6 - iter 4/44 - loss 1.67724013 - samples/sec: 106.90 - lr: 0.100000
# 2020-12-08 05:56:30,789 epoch 6 - iter 8/44 - loss 1.46085814 - samples/sec: 122.72 - lr: 0.100000
# 2020-12-08 05:56:31,936 epoch 6 - iter 12/44 - loss 1.56682123 - samples/sec: 111.71 - lr: 0.100000
# 2020-12-08 05:56:32,978 epoch 6 - iter 16/44 - loss 1.61236640 - samples/sec: 122.94 - lr: 0.100000
# 2020-12-08 05:56:34,087 epoch 6 - iter 20/44 - loss 1.64541262 - samples/sec: 115.52 - lr: 0.100000
# 2020-12-08 05:56:35,153 epoch 6 - iter 24/44 - loss 1.77220440 - samples/sec: 120.16 - lr: 0.100000
# 2020-12-08 05:56:36,236 epoch 6 - iter 28/44 - loss 1.79340410 - samples/sec: 118.30 - lr: 0.100000
# 2020-12-08 05:56:37,452 epoch 6 - iter 32/44 - loss 1.83865534 - samples/sec: 105.37 - lr: 0.100000
# 2020-12-08 05:56:38,502 epoch 6 - iter 36/44 - loss 1.76655858 - samples/sec: 122.07 - lr: 0.100000
# 2020-12-08 05:56:39,536 epoch 6 - iter 40/44 - loss 1.76398591 - samples/sec: 123.88 - lr: 0.100000
# 2020-12-08 05:56:40,633 epoch 6 - iter 44/44 - loss 1.72932042 - samples/sec: 116.83 - lr: 0.100000
# 2020-12-08 05:56:40,634 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:56:40,635 EPOCH 6 done: loss 1.7293 - lr 0.1000000
# 2020-12-08 05:56:56,487 DEV : loss 1.4114553928375244 - score 0.8582
# 2020-12-08 05:56:56,737 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 05:57:03,631 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 05:57:04,763 epoch 7 - iter 4/44 - loss 1.57862310 - samples/sec: 113.55 - lr: 0.100000
# 2020-12-08 05:57:05,822 epoch 7 - iter 8/44 - loss 1.52319167 - samples/sec: 120.95 - lr: 0.100000
# 2020-12-08 05:57:06,867 epoch 7 - iter 12/44 - loss 1.61381840 - samples/sec: 122.68 - lr: 0.100000
# 2020-12-08 05:57:07,858 epoch 7 - iter 16/44 - loss 1.59677060 - samples/sec: 129.26 - lr: 0.100000
# 2020-12-08 05:57:08,920 epoch 7 - iter 20/44 - loss 1.59502816 - samples/sec: 120.68 - lr: 0.100000
# 2020-12-08 05:57:09,977 epoch 7 - iter 24/44 - loss 1.58699119 - samples/sec: 121.18 - lr: 0.100000
# 2020-12-08 05:57:11,098 epoch 7 - iter 28/44 - loss 1.60055028 - samples/sec: 114.27 - lr: 0.100000
# 2020-12-08 05:57:12,183 epoch 7 - iter 32/44 - loss 1.57558815 - samples/sec: 118.14 - lr: 0.100000
# 2020-12-08 05:57:13,389 epoch 7 - iter 36/44 - loss 1.62073206 - samples/sec: 106.17 - lr: 0.100000
# 2020-12-08 05:57:14,618 epoch 7 - iter 40/44 - loss 1.55403518 - samples/sec: 104.22 - lr: 0.100000
# 2020-12-08 05:57:15,817 epoch 7 - iter 44/44 - loss 1.54773894 - samples/sec: 106.93 - lr: 0.100000
# 2020-12-08 05:57:15,817 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:57:15,818 EPOCH 7 done: loss 1.5477 - lr 0.1000000
# 2020-12-08 05:57:31,040 DEV : loss 1.3786503076553345 - score 0.8496
# 2020-12-08 05:57:31,307 BAD EPOCHS (no improvement): 1
# 2020-12-08 05:57:31,308 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 05:57:32,455 epoch 8 - iter 4/44 - loss 1.68385494 - samples/sec: 111.84 - lr: 0.100000
# 2020-12-08 05:57:33,461 epoch 8 - iter 8/44 - loss 1.61246384 - samples/sec: 127.36 - lr: 0.100000
# 2020-12-08 05:57:34,660 epoch 8 - iter 12/44 - loss 1.58646636 - samples/sec: 106.79 - lr: 0.100000
# 2020-12-08 05:57:35,817 epoch 8 - iter 16/44 - loss 1.57266695 - samples/sec: 110.69 - lr: 0.100000
# 2020-12-08 05:57:36,845 epoch 8 - iter 20/44 - loss 1.54409059 - samples/sec: 124.75 - lr: 0.100000
# 2020-12-08 05:57:38,016 epoch 8 - iter 24/44 - loss 1.48585645 - samples/sec: 109.39 - lr: 0.100000
# 2020-12-08 05:57:39,066 epoch 8 - iter 28/44 - loss 1.44374161 - samples/sec: 122.05 - lr: 0.100000
# 2020-12-08 05:57:40,165 epoch 8 - iter 32/44 - loss 1.40464557 - samples/sec: 116.57 - lr: 0.100000
# 2020-12-08 05:57:41,300 epoch 8 - iter 36/44 - loss 1.40665580 - samples/sec: 112.91 - lr: 0.100000
# 2020-12-08 05:57:42,337 epoch 8 - iter 40/44 - loss 1.45797987 - samples/sec: 123.50 - lr: 0.100000
# 2020-12-08 05:57:43,356 epoch 8 - iter 44/44 - loss 1.43396798 - samples/sec: 125.73 - lr: 0.100000
# 2020-12-08 05:57:43,357 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:57:43,358 EPOCH 8 done: loss 1.4340 - lr 0.1000000
# 2020-12-08 05:57:59,324 DEV : loss 1.2818254232406616 - score 0.872
# 2020-12-08 05:57:59,576 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 05:58:06,120 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 05:58:07,213 epoch 9 - iter 4/44 - loss 1.41130967 - samples/sec: 117.43 - lr: 0.100000
# 2020-12-08 05:58:08,406 epoch 9 - iter 8/44 - loss 1.41727126 - samples/sec: 107.39 - lr: 0.100000
# 2020-12-08 05:58:09,515 epoch 9 - iter 12/44 - loss 1.30363043 - samples/sec: 115.53 - lr: 0.100000
# 2020-12-08 05:58:10,542 epoch 9 - iter 16/44 - loss 1.29769764 - samples/sec: 124.83 - lr: 0.100000
# 2020-12-08 05:58:11,670 epoch 9 - iter 20/44 - loss 1.31115211 - samples/sec: 113.50 - lr: 0.100000
# 2020-12-08 05:58:12,747 epoch 9 - iter 24/44 - loss 1.24470310 - samples/sec: 119.02 - lr: 0.100000
# 2020-12-08 05:58:13,876 epoch 9 - iter 28/44 - loss 1.26281631 - samples/sec: 113.51 - lr: 0.100000
# 2020-12-08 05:58:15,053 epoch 9 - iter 32/44 - loss 1.24693284 - samples/sec: 108.85 - lr: 0.100000
# 2020-12-08 05:58:16,224 epoch 9 - iter 36/44 - loss 1.22533406 - samples/sec: 109.33 - lr: 0.100000
# 2020-12-08 05:58:17,258 epoch 9 - iter 40/44 - loss 1.22039046 - samples/sec: 123.99 - lr: 0.100000
# 2020-12-08 05:58:18,336 epoch 9 - iter 44/44 - loss 1.22407140 - samples/sec: 118.86 - lr: 0.100000
# 2020-12-08 05:58:18,337 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:58:18,337 EPOCH 9 done: loss 1.2241 - lr 0.1000000
# 2020-12-08 05:58:34,045 DEV : loss 1.2544020414352417 - score 0.8717
# 2020-12-08 05:58:34,301 BAD EPOCHS (no improvement): 1
# 2020-12-08 05:58:34,302 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 05:58:35,322 epoch 10 - iter 4/44 - loss 0.90694785 - samples/sec: 125.73 - lr: 0.100000
# 2020-12-08 05:58:36,373 epoch 10 - iter 8/44 - loss 1.16505351 - samples/sec: 121.92 - lr: 0.100000
# 2020-12-08 05:58:37,426 epoch 10 - iter 12/44 - loss 1.17676690 - samples/sec: 121.66 - lr: 0.100000
# 2020-12-08 05:58:38,511 epoch 10 - iter 16/44 - loss 1.10672483 - samples/sec: 118.10 - lr: 0.100000
# 2020-12-08 05:58:39,758 epoch 10 - iter 20/44 - loss 1.17310813 - samples/sec: 102.76 - lr: 0.100000
# 2020-12-08 05:58:40,792 epoch 10 - iter 24/44 - loss 1.11248970 - samples/sec: 123.98 - lr: 0.100000
# 2020-12-08 05:58:42,044 epoch 10 - iter 28/44 - loss 1.15814199 - samples/sec: 102.27 - lr: 0.100000
# 2020-12-08 05:58:43,197 epoch 10 - iter 32/44 - loss 1.18596405 - samples/sec: 111.09 - lr: 0.100000
# 2020-12-08 05:58:44,426 epoch 10 - iter 36/44 - loss 1.15093709 - samples/sec: 104.29 - lr: 0.100000
# 2020-12-08 05:58:45,613 epoch 10 - iter 40/44 - loss 1.11937751 - samples/sec: 107.90 - lr: 0.100000
# 2020-12-08 05:58:46,739 epoch 10 - iter 44/44 - loss 1.12810168 - samples/sec: 113.77 - lr: 0.100000
# 2020-12-08 05:58:46,740 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:58:46,741 EPOCH 10 done: loss 1.1281 - lr 0.1000000
# 2020-12-08 05:59:02,619 DEV : loss 1.226677656173706 - score 0.8861
# 2020-12-08 05:59:02,889 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 05:59:10,299 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 05:59:11,398 epoch 11 - iter 4/44 - loss 1.18675391 - samples/sec: 117.34 - lr: 0.100000
# 2020-12-08 05:59:12,523 epoch 11 - iter 8/44 - loss 1.16179267 - samples/sec: 113.86 - lr: 0.100000
# 2020-12-08 05:59:13,544 epoch 11 - iter 12/44 - loss 1.02169924 - samples/sec: 125.51 - lr: 0.100000
# 2020-12-08 05:59:14,604 epoch 11 - iter 16/44 - loss 1.00334627 - samples/sec: 121.08 - lr: 0.100000
# 2020-12-08 05:59:15,636 epoch 11 - iter 20/44 - loss 1.03573364 - samples/sec: 124.10 - lr: 0.100000
# 2020-12-08 05:59:16,789 epoch 11 - iter 24/44 - loss 1.05130254 - samples/sec: 111.21 - lr: 0.100000
# 2020-12-08 05:59:17,804 epoch 11 - iter 28/44 - loss 1.02988286 - samples/sec: 126.23 - lr: 0.100000
# 2020-12-08 05:59:19,023 epoch 11 - iter 32/44 - loss 1.10146203 - samples/sec: 105.09 - lr: 0.100000
# 2020-12-08 05:59:20,059 epoch 11 - iter 36/44 - loss 1.08533456 - samples/sec: 123.73 - lr: 0.100000
# 2020-12-08 05:59:21,169 epoch 11 - iter 40/44 - loss 1.08715513 - samples/sec: 115.43 - lr: 0.100000
# 2020-12-08 05:59:22,243 epoch 11 - iter 44/44 - loss 1.09595594 - samples/sec: 119.29 - lr: 0.100000
# 2020-12-08 05:59:22,244 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:59:22,244 EPOCH 11 done: loss 1.0960 - lr 0.1000000
# 2020-12-08 05:59:36,951 DEV : loss 1.2373465299606323 - score 0.8811
# 2020-12-08 05:59:37,202 BAD EPOCHS (no improvement): 1
# 2020-12-08 05:59:37,202 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 05:59:38,264 epoch 12 - iter 4/44 - loss 0.72427155 - samples/sec: 120.80 - lr: 0.100000
# 2020-12-08 05:59:39,329 epoch 12 - iter 8/44 - loss 0.77169839 - samples/sec: 120.29 - lr: 0.100000
# 2020-12-08 05:59:40,504 epoch 12 - iter 12/44 - loss 1.00244842 - samples/sec: 109.02 - lr: 0.100000
# 2020-12-08 05:59:41,567 epoch 12 - iter 16/44 - loss 0.96739043 - samples/sec: 120.55 - lr: 0.100000
# 2020-12-08 05:59:42,679 epoch 12 - iter 20/44 - loss 0.90820049 - samples/sec: 115.25 - lr: 0.100000
# 2020-12-08 05:59:43,699 epoch 12 - iter 24/44 - loss 0.90541270 - samples/sec: 125.60 - lr: 0.100000
# 2020-12-08 05:59:44,764 epoch 12 - iter 28/44 - loss 0.89351381 - samples/sec: 120.34 - lr: 0.100000
# 2020-12-08 05:59:45,975 epoch 12 - iter 32/44 - loss 0.93754624 - samples/sec: 105.81 - lr: 0.100000
# 2020-12-08 05:59:47,129 epoch 12 - iter 36/44 - loss 0.95447771 - samples/sec: 111.05 - lr: 0.100000
# 2020-12-08 05:59:48,203 epoch 12 - iter 40/44 - loss 0.95134264 - samples/sec: 119.38 - lr: 0.100000
# 2020-12-08 05:59:49,258 epoch 12 - iter 44/44 - loss 0.94580917 - samples/sec: 121.43 - lr: 0.100000
# 2020-12-08 05:59:49,259 ----------------------------------------------------------------------------------------------------
# 2020-12-08 05:59:49,260 EPOCH 12 done: loss 0.9458 - lr 0.1000000
# 2020-12-08 06:00:04,494 DEV : loss 1.2195812463760376 - score 0.8826
# 2020-12-08 06:00:04,752 BAD EPOCHS (no improvement): 2
# 2020-12-08 06:00:04,753 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:00:05,829 epoch 13 - iter 4/44 - loss 0.82496968 - samples/sec: 119.23 - lr: 0.100000
# 2020-12-08 06:00:06,906 epoch 13 - iter 8/44 - loss 0.74222647 - samples/sec: 118.96 - lr: 0.100000
# 2020-12-08 06:00:07,915 epoch 13 - iter 12/44 - loss 0.75130337 - samples/sec: 127.02 - lr: 0.100000
# 2020-12-08 06:00:09,010 epoch 13 - iter 16/44 - loss 0.76777128 - samples/sec: 117.05 - lr: 0.100000
# 2020-12-08 06:00:10,113 epoch 13 - iter 20/44 - loss 0.82062649 - samples/sec: 116.20 - lr: 0.100000
# 2020-12-08 06:00:11,343 epoch 13 - iter 24/44 - loss 0.85261048 - samples/sec: 104.16 - lr: 0.100000
# 2020-12-08 06:00:12,360 epoch 13 - iter 28/44 - loss 0.84217558 - samples/sec: 126.09 - lr: 0.100000
# 2020-12-08 06:00:13,353 epoch 13 - iter 32/44 - loss 0.82782281 - samples/sec: 129.11 - lr: 0.100000
# 2020-12-08 06:00:14,497 epoch 13 - iter 36/44 - loss 0.84941430 - samples/sec: 111.90 - lr: 0.100000
# 2020-12-08 06:00:15,629 epoch 13 - iter 40/44 - loss 0.85489572 - samples/sec: 113.24 - lr: 0.100000
# 2020-12-08 06:00:16,623 epoch 13 - iter 44/44 - loss 0.88245398 - samples/sec: 128.86 - lr: 0.100000
# 2020-12-08 06:00:16,625 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:00:16,626 EPOCH 13 done: loss 0.8825 - lr 0.1000000
# 2020-12-08 06:00:33,197 DEV : loss 1.1779029369354248 - score 0.8883
# 2020-12-08 06:00:33,447 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:00:39,982 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:00:41,115 epoch 14 - iter 4/44 - loss 1.16905192 - samples/sec: 113.86 - lr: 0.100000
# 2020-12-08 06:00:42,107 epoch 14 - iter 8/44 - loss 0.94995094 - samples/sec: 129.15 - lr: 0.100000
# 2020-12-08 06:00:43,060 epoch 14 - iter 12/44 - loss 0.86047719 - samples/sec: 134.39 - lr: 0.100000
# 2020-12-08 06:00:44,254 epoch 14 - iter 16/44 - loss 0.85941979 - samples/sec: 107.34 - lr: 0.100000
# 2020-12-08 06:00:45,397 epoch 14 - iter 20/44 - loss 0.86280076 - samples/sec: 112.04 - lr: 0.100000
# 2020-12-08 06:00:46,377 epoch 14 - iter 24/44 - loss 0.84246331 - samples/sec: 130.75 - lr: 0.100000
# 2020-12-08 06:00:47,522 epoch 14 - iter 28/44 - loss 0.84383314 - samples/sec: 111.87 - lr: 0.100000
# 2020-12-08 06:00:48,774 epoch 14 - iter 32/44 - loss 0.84148292 - samples/sec: 102.30 - lr: 0.100000
# 2020-12-08 06:00:49,911 epoch 14 - iter 36/44 - loss 0.85498463 - samples/sec: 112.75 - lr: 0.100000
# 2020-12-08 06:00:51,022 epoch 14 - iter 40/44 - loss 0.87345943 - samples/sec: 115.34 - lr: 0.100000
# 2020-12-08 06:00:52,070 epoch 14 - iter 44/44 - loss 0.87066001 - samples/sec: 122.16 - lr: 0.100000
# 2020-12-08 06:00:52,071 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:00:52,072 EPOCH 14 done: loss 0.8707 - lr 0.1000000
# 2020-12-08 06:01:07,706 DEV : loss 1.18573796749115 - score 0.8922
# 2020-12-08 06:01:07,966 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:01:15,413 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:01:16,486 epoch 15 - iter 4/44 - loss 0.78750159 - samples/sec: 119.57 - lr: 0.100000
# 2020-12-08 06:01:17,632 epoch 15 - iter 8/44 - loss 0.93151871 - samples/sec: 111.81 - lr: 0.100000
# 2020-12-08 06:01:18,609 epoch 15 - iter 12/44 - loss 0.89408722 - samples/sec: 131.14 - lr: 0.100000
# 2020-12-08 06:01:19,792 epoch 15 - iter 16/44 - loss 0.87409978 - samples/sec: 108.34 - lr: 0.100000
# 2020-12-08 06:01:21,008 epoch 15 - iter 20/44 - loss 0.81105437 - samples/sec: 105.36 - lr: 0.100000
# 2020-12-08 06:01:22,190 epoch 15 - iter 24/44 - loss 0.75571891 - samples/sec: 108.31 - lr: 0.100000
# 2020-12-08 06:01:23,340 epoch 15 - iter 28/44 - loss 0.77363367 - samples/sec: 111.42 - lr: 0.100000
# 2020-12-08 06:01:24,311 epoch 15 - iter 32/44 - loss 0.75897769 - samples/sec: 131.96 - lr: 0.100000
# 2020-12-08 06:01:25,371 epoch 15 - iter 36/44 - loss 0.77155517 - samples/sec: 120.81 - lr: 0.100000
# 2020-12-08 06:01:26,308 epoch 15 - iter 40/44 - loss 0.76119815 - samples/sec: 136.78 - lr: 0.100000
# 2020-12-08 06:01:27,452 epoch 15 - iter 44/44 - loss 0.76861750 - samples/sec: 112.03 - lr: 0.100000
# 2020-12-08 06:01:27,453 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:01:27,453 EPOCH 15 done: loss 0.7686 - lr 0.1000000
# 2020-12-08 06:01:43,968 DEV : loss 1.159437894821167 - score 0.8929
# 2020-12-08 06:01:44,249 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:01:51,226 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:01:52,304 epoch 16 - iter 4/44 - loss 0.73137565 - samples/sec: 119.73 - lr: 0.100000
# 2020-12-08 06:01:53,475 epoch 16 - iter 8/44 - loss 0.66943556 - samples/sec: 109.46 - lr: 0.100000
# 2020-12-08 06:01:54,555 epoch 16 - iter 12/44 - loss 0.70572916 - samples/sec: 118.60 - lr: 0.100000
# 2020-12-08 06:01:55,704 epoch 16 - iter 16/44 - loss 0.74460641 - samples/sec: 111.44 - lr: 0.100000
# 2020-12-08 06:01:56,756 epoch 16 - iter 20/44 - loss 0.76534752 - samples/sec: 121.86 - lr: 0.100000
# 2020-12-08 06:01:57,969 epoch 16 - iter 24/44 - loss 0.73869548 - samples/sec: 105.63 - lr: 0.100000
# 2020-12-08 06:01:59,092 epoch 16 - iter 28/44 - loss 0.73182041 - samples/sec: 114.08 - lr: 0.100000
# 2020-12-08 06:02:00,131 epoch 16 - iter 32/44 - loss 0.74582605 - samples/sec: 123.33 - lr: 0.100000
# 2020-12-08 06:02:01,194 epoch 16 - iter 36/44 - loss 0.74728446 - samples/sec: 120.41 - lr: 0.100000
# 2020-12-08 06:02:02,217 epoch 16 - iter 40/44 - loss 0.75990366 - samples/sec: 125.26 - lr: 0.100000
# 2020-12-08 06:02:03,417 epoch 16 - iter 44/44 - loss 0.75737867 - samples/sec: 106.83 - lr: 0.100000
# 2020-12-08 06:02:03,417 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:02:03,418 EPOCH 16 done: loss 0.7574 - lr 0.1000000
# 2020-12-08 06:02:18,756 DEV : loss 1.2716742753982544 - score 0.8836
# 2020-12-08 06:02:19,020 BAD EPOCHS (no improvement): 1
# 2020-12-08 06:02:19,021 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:02:20,296 epoch 17 - iter 4/44 - loss 0.64372232 - samples/sec: 100.61 - lr: 0.100000
# 2020-12-08 06:02:21,423 epoch 17 - iter 8/44 - loss 0.70893807 - samples/sec: 113.67 - lr: 0.100000
# 2020-12-08 06:02:22,485 epoch 17 - iter 12/44 - loss 0.67465510 - samples/sec: 120.64 - lr: 0.100000
# 2020-12-08 06:02:23,636 epoch 17 - iter 16/44 - loss 0.69172770 - samples/sec: 111.35 - lr: 0.100000
# 2020-12-08 06:02:24,860 epoch 17 - iter 20/44 - loss 0.70835646 - samples/sec: 104.74 - lr: 0.100000
# 2020-12-08 06:02:25,940 epoch 17 - iter 24/44 - loss 0.69098896 - samples/sec: 118.59 - lr: 0.100000
# 2020-12-08 06:02:27,011 epoch 17 - iter 28/44 - loss 0.70544165 - samples/sec: 119.57 - lr: 0.100000
# 2020-12-08 06:02:28,057 epoch 17 - iter 32/44 - loss 0.67036056 - samples/sec: 122.54 - lr: 0.100000
# 2020-12-08 06:02:29,166 epoch 17 - iter 36/44 - loss 0.67589122 - samples/sec: 115.53 - lr: 0.100000
# 2020-12-08 06:02:30,244 epoch 17 - iter 40/44 - loss 0.67465074 - samples/sec: 118.81 - lr: 0.100000
# 2020-12-08 06:02:31,319 epoch 17 - iter 44/44 - loss 0.67961112 - samples/sec: 119.24 - lr: 0.100000
# 2020-12-08 06:02:31,320 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:02:31,320 EPOCH 17 done: loss 0.6796 - lr 0.1000000
# 2020-12-08 06:02:47,283 DEV : loss 1.258374571800232 - score 0.8801
# 2020-12-08 06:02:47,539 BAD EPOCHS (no improvement): 2
# 2020-12-08 06:02:47,540 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:02:48,607 epoch 18 - iter 4/44 - loss 0.55154595 - samples/sec: 120.31 - lr: 0.100000
# 2020-12-08 06:02:49,677 epoch 18 - iter 8/44 - loss 0.47301859 - samples/sec: 119.65 - lr: 0.100000
# 2020-12-08 06:02:50,972 epoch 18 - iter 12/44 - loss 0.52842566 - samples/sec: 98.91 - lr: 0.100000
# 2020-12-08 06:02:52,084 epoch 18 - iter 16/44 - loss 0.54698816 - samples/sec: 115.28 - lr: 0.100000
# 2020-12-08 06:02:53,198 epoch 18 - iter 20/44 - loss 0.55670097 - samples/sec: 114.97 - lr: 0.100000
# 2020-12-08 06:02:54,212 epoch 18 - iter 24/44 - loss 0.57688413 - samples/sec: 126.27 - lr: 0.100000
# 2020-12-08 06:02:55,489 epoch 18 - iter 28/44 - loss 0.59711714 - samples/sec: 100.34 - lr: 0.100000
# 2020-12-08 06:02:56,612 epoch 18 - iter 32/44 - loss 0.63174239 - samples/sec: 114.13 - lr: 0.100000
# 2020-12-08 06:02:57,890 epoch 18 - iter 36/44 - loss 0.61412643 - samples/sec: 100.17 - lr: 0.100000
# 2020-12-08 06:02:59,024 epoch 18 - iter 40/44 - loss 0.62092901 - samples/sec: 113.01 - lr: 0.100000
# 2020-12-08 06:03:00,227 epoch 18 - iter 44/44 - loss 0.62480030 - samples/sec: 106.89 - lr: 0.100000
# 2020-12-08 06:03:00,229 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:03:00,234 EPOCH 18 done: loss 0.6248 - lr 0.1000000
# 2020-12-08 06:03:17,353 DEV : loss 1.2104872465133667 - score 0.8909
# 2020-12-08 06:03:17,672 BAD EPOCHS (no improvement): 3
# 2020-12-08 06:03:17,673 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:03:19,000 epoch 19 - iter 4/44 - loss 0.62348481 - samples/sec: 96.64 - lr: 0.100000
# 2020-12-08 06:03:20,416 epoch 19 - iter 8/44 - loss 0.65691274 - samples/sec: 90.52 - lr: 0.100000
# 2020-12-08 06:03:21,598 epoch 19 - iter 12/44 - loss 0.70270888 - samples/sec: 108.44 - lr: 0.100000
# 2020-12-08 06:03:22,716 epoch 19 - iter 16/44 - loss 0.70292816 - samples/sec: 114.59 - lr: 0.100000
# 2020-12-08 06:03:23,906 epoch 19 - iter 20/44 - loss 0.70170485 - samples/sec: 107.66 - lr: 0.100000
# 2020-12-08 06:03:25,240 epoch 19 - iter 24/44 - loss 0.69512164 - samples/sec: 96.02 - lr: 0.100000
# 2020-12-08 06:03:26,325 epoch 19 - iter 28/44 - loss 0.67081107 - samples/sec: 118.05 - lr: 0.100000
# 2020-12-08 06:03:27,559 epoch 19 - iter 32/44 - loss 0.69551339 - samples/sec: 103.79 - lr: 0.100000
# 2020-12-08 06:03:28,568 epoch 19 - iter 36/44 - loss 0.69241143 - samples/sec: 127.02 - lr: 0.100000
# 2020-12-08 06:03:29,841 epoch 19 - iter 40/44 - loss 0.67984958 - samples/sec: 100.57 - lr: 0.100000
# 2020-12-08 06:03:31,144 epoch 19 - iter 44/44 - loss 0.67178609 - samples/sec: 98.30 - lr: 0.100000
# 2020-12-08 06:03:31,145 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:03:31,146 EPOCH 19 done: loss 0.6718 - lr 0.1000000
# 2020-12-08 06:03:47,560 DEV : loss 1.2070221900939941 - score 0.8942
# 2020-12-08 06:03:47,818 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:03:54,477 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:03:55,696 epoch 20 - iter 4/44 - loss 0.69944309 - samples/sec: 106.18 - lr: 0.100000
# 2020-12-08 06:03:56,825 epoch 20 - iter 8/44 - loss 0.59307859 - samples/sec: 113.45 - lr: 0.100000
# 2020-12-08 06:03:57,989 epoch 20 - iter 12/44 - loss 0.53674625 - samples/sec: 110.12 - lr: 0.100000
# 2020-12-08 06:03:59,071 epoch 20 - iter 16/44 - loss 0.55850735 - samples/sec: 118.31 - lr: 0.100000
# 2020-12-08 06:04:00,317 epoch 20 - iter 20/44 - loss 0.61184651 - samples/sec: 102.86 - lr: 0.100000
# 2020-12-08 06:04:01,328 epoch 20 - iter 24/44 - loss 0.58938188 - samples/sec: 126.83 - lr: 0.100000
# 2020-12-08 06:04:02,344 epoch 20 - iter 28/44 - loss 0.58575013 - samples/sec: 126.09 - lr: 0.100000
# 2020-12-08 06:04:03,467 epoch 20 - iter 32/44 - loss 0.56965200 - samples/sec: 114.04 - lr: 0.100000
# 2020-12-08 06:04:04,570 epoch 20 - iter 36/44 - loss 0.57557643 - samples/sec: 116.11 - lr: 0.100000
# 2020-12-08 06:04:05,625 epoch 20 - iter 40/44 - loss 0.58640472 - samples/sec: 121.48 - lr: 0.100000
# 2020-12-08 06:04:06,769 epoch 20 - iter 44/44 - loss 0.59993822 - samples/sec: 112.10 - lr: 0.100000
# 2020-12-08 06:04:06,770 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:04:06,770 EPOCH 20 done: loss 0.5999 - lr 0.1000000
# 2020-12-08 06:04:21,999 DEV : loss 1.1818357706069946 - score 0.8962
# 2020-12-08 06:04:22,252 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:04:29,134 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:04:30,303 epoch 21 - iter 4/44 - loss 0.48566787 - samples/sec: 110.28 - lr: 0.100000
# 2020-12-08 06:04:31,835 epoch 21 - iter 8/44 - loss 0.51162653 - samples/sec: 83.60 - lr: 0.100000
# 2020-12-08 06:04:32,889 epoch 21 - iter 12/44 - loss 0.48861560 - samples/sec: 121.64 - lr: 0.100000
# 2020-12-08 06:04:33,804 epoch 21 - iter 16/44 - loss 0.46521936 - samples/sec: 140.15 - lr: 0.100000
# 2020-12-08 06:04:34,845 epoch 21 - iter 20/44 - loss 0.51219798 - samples/sec: 123.04 - lr: 0.100000
# 2020-12-08 06:04:36,046 epoch 21 - iter 24/44 - loss 0.50366512 - samples/sec: 106.62 - lr: 0.100000
# 2020-12-08 06:04:37,026 epoch 21 - iter 28/44 - loss 0.50980721 - samples/sec: 131.03 - lr: 0.100000
# 2020-12-08 06:04:38,121 epoch 21 - iter 32/44 - loss 0.50272791 - samples/sec: 116.98 - lr: 0.100000
# 2020-12-08 06:04:39,143 epoch 21 - iter 36/44 - loss 0.51106629 - samples/sec: 125.40 - lr: 0.100000
# 2020-12-08 06:04:40,181 epoch 21 - iter 40/44 - loss 0.53646108 - samples/sec: 123.43 - lr: 0.100000
# 2020-12-08 06:04:41,308 epoch 21 - iter 44/44 - loss 0.55162831 - samples/sec: 113.62 - lr: 0.100000
# 2020-12-08 06:04:41,309 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:04:41,310 EPOCH 21 done: loss 0.5516 - lr 0.1000000
# 2020-12-08 06:04:57,310 DEV : loss 1.1672769784927368 - score 0.8993
# 2020-12-08 06:04:57,561 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:05:04,068 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:05:05,265 epoch 22 - iter 4/44 - loss 0.78850873 - samples/sec: 107.67 - lr: 0.100000
# 2020-12-08 06:05:06,228 epoch 22 - iter 8/44 - loss 0.61768071 - samples/sec: 133.11 - lr: 0.100000
# 2020-12-08 06:05:07,355 epoch 22 - iter 12/44 - loss 0.55645801 - samples/sec: 113.65 - lr: 0.100000
# 2020-12-08 06:05:08,460 epoch 22 - iter 16/44 - loss 0.57409993 - samples/sec: 115.96 - lr: 0.100000
# 2020-12-08 06:05:09,614 epoch 22 - iter 20/44 - loss 0.53591114 - samples/sec: 111.06 - lr: 0.100000
# 2020-12-08 06:05:10,672 epoch 22 - iter 24/44 - loss 0.52582359 - samples/sec: 121.01 - lr: 0.100000
# 2020-12-08 06:05:11,765 epoch 22 - iter 28/44 - loss 0.50986431 - samples/sec: 117.26 - lr: 0.100000
# 2020-12-08 06:05:12,818 epoch 22 - iter 32/44 - loss 0.51107958 - samples/sec: 121.72 - lr: 0.100000
# 2020-12-08 06:05:13,950 epoch 22 - iter 36/44 - loss 0.52738994 - samples/sec: 113.12 - lr: 0.100000
# 2020-12-08 06:05:15,099 epoch 22 - iter 40/44 - loss 0.51305428 - samples/sec: 111.53 - lr: 0.100000
# 2020-12-08 06:05:16,172 epoch 22 - iter 44/44 - loss 0.52033450 - samples/sec: 119.38 - lr: 0.100000
# 2020-12-08 06:05:16,173 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:05:16,174 EPOCH 22 done: loss 0.5203 - lr 0.1000000
# 2020-12-08 06:05:30,857 DEV : loss 1.1600385904312134 - score 0.9004
# 2020-12-08 06:05:31,106 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:05:36,504 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:05:37,636 epoch 23 - iter 4/44 - loss 0.69976465 - samples/sec: 113.85 - lr: 0.100000
# 2020-12-08 06:05:38,641 epoch 23 - iter 8/44 - loss 0.67942486 - samples/sec: 127.48 - lr: 0.100000
# 2020-12-08 06:05:39,806 epoch 23 - iter 12/44 - loss 0.64821998 - samples/sec: 109.95 - lr: 0.100000
# 2020-12-08 06:05:40,903 epoch 23 - iter 16/44 - loss 0.58904469 - samples/sec: 116.80 - lr: 0.100000
# 2020-12-08 06:05:41,919 epoch 23 - iter 20/44 - loss 0.53751659 - samples/sec: 126.05 - lr: 0.100000
# 2020-12-08 06:05:43,062 epoch 23 - iter 24/44 - loss 0.54779310 - samples/sec: 112.08 - lr: 0.100000
# 2020-12-08 06:05:44,055 epoch 23 - iter 28/44 - loss 0.53786730 - samples/sec: 129.14 - lr: 0.100000
# 2020-12-08 06:05:45,040 epoch 23 - iter 32/44 - loss 0.51337369 - samples/sec: 130.04 - lr: 0.100000
# 2020-12-08 06:05:46,108 epoch 23 - iter 36/44 - loss 0.52343649 - samples/sec: 119.99 - lr: 0.100000
# 2020-12-08 06:05:47,145 epoch 23 - iter 40/44 - loss 0.50957306 - samples/sec: 123.46 - lr: 0.100000
# 2020-12-08 06:05:48,947 epoch 23 - iter 44/44 - loss 0.52084709 - samples/sec: 71.09 - lr: 0.100000
# 2020-12-08 06:05:48,948 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:05:48,948 EPOCH 23 done: loss 0.5208 - lr 0.1000000
# 2020-12-08 06:06:03,620 DEV : loss 1.2256125211715698 - score 0.895
# 2020-12-08 06:06:03,887 BAD EPOCHS (no improvement): 1
# 2020-12-08 06:06:03,888 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:06:04,931 epoch 24 - iter 4/44 - loss 0.54541066 - samples/sec: 123.08 - lr: 0.100000
# 2020-12-08 06:06:06,079 epoch 24 - iter 8/44 - loss 0.61663188 - samples/sec: 111.63 - lr: 0.100000
# 2020-12-08 06:06:07,133 epoch 24 - iter 12/44 - loss 0.59947983 - samples/sec: 121.58 - lr: 0.100000
# 2020-12-08 06:06:08,170 epoch 24 - iter 16/44 - loss 0.58660102 - samples/sec: 123.49 - lr: 0.100000
# 2020-12-08 06:06:09,239 epoch 24 - iter 20/44 - loss 0.56123152 - samples/sec: 119.87 - lr: 0.100000
# 2020-12-08 06:06:10,271 epoch 24 - iter 24/44 - loss 0.55264004 - samples/sec: 124.12 - lr: 0.100000
# 2020-12-08 06:06:11,315 epoch 24 - iter 28/44 - loss 0.52295430 - samples/sec: 122.73 - lr: 0.100000
# 2020-12-08 06:06:12,396 epoch 24 - iter 32/44 - loss 0.52298590 - samples/sec: 118.50 - lr: 0.100000
# 2020-12-08 06:06:13,452 epoch 24 - iter 36/44 - loss 0.52104539 - samples/sec: 121.38 - lr: 0.100000
# 2020-12-08 06:06:14,593 epoch 24 - iter 40/44 - loss 0.52961834 - samples/sec: 112.21 - lr: 0.100000
# 2020-12-08 06:06:15,643 epoch 24 - iter 44/44 - loss 0.52941292 - samples/sec: 121.99 - lr: 0.100000
# 2020-12-08 06:06:15,644 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:06:15,645 EPOCH 24 done: loss 0.5294 - lr 0.1000000
# 2020-12-08 06:06:30,371 DEV : loss 1.1953942775726318 - score 0.8956
# 2020-12-08 06:06:30,636 BAD EPOCHS (no improvement): 2
# 2020-12-08 06:06:30,637 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:06:31,771 epoch 25 - iter 4/44 - loss 0.62497392 - samples/sec: 113.18 - lr: 0.100000
# 2020-12-08 06:06:32,789 epoch 25 - iter 8/44 - loss 0.45447031 - samples/sec: 125.80 - lr: 0.100000
# 2020-12-08 06:06:33,764 epoch 25 - iter 12/44 - loss 0.42785349 - samples/sec: 131.55 - lr: 0.100000
# 2020-12-08 06:06:34,872 epoch 25 - iter 16/44 - loss 0.45788433 - samples/sec: 115.94 - lr: 0.100000
# 2020-12-08 06:06:36,007 epoch 25 - iter 20/44 - loss 0.42758602 - samples/sec: 112.92 - lr: 0.100000
# 2020-12-08 06:06:37,060 epoch 25 - iter 24/44 - loss 0.41675480 - samples/sec: 121.73 - lr: 0.100000
# 2020-12-08 06:06:38,127 epoch 25 - iter 28/44 - loss 0.45272841 - samples/sec: 120.03 - lr: 0.100000
# 2020-12-08 06:06:39,230 epoch 25 - iter 32/44 - loss 0.48715777 - samples/sec: 116.11 - lr: 0.100000
# 2020-12-08 06:06:40,354 epoch 25 - iter 36/44 - loss 0.50223062 - samples/sec: 114.04 - lr: 0.100000
# 2020-12-08 06:06:41,319 epoch 25 - iter 40/44 - loss 0.49799039 - samples/sec: 132.70 - lr: 0.100000
# 2020-12-08 06:06:42,344 epoch 25 - iter 44/44 - loss 0.51197813 - samples/sec: 125.08 - lr: 0.100000
# 2020-12-08 06:06:42,344 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:06:42,346 EPOCH 25 done: loss 0.5120 - lr 0.1000000
# 2020-12-08 06:06:57,825 DEV : loss 1.22847318649292 - score 0.8969
# 2020-12-08 06:06:58,070 BAD EPOCHS (no improvement): 3
# 2020-12-08 06:06:58,071 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:06:59,136 epoch 26 - iter 4/44 - loss 0.43880730 - samples/sec: 120.51 - lr: 0.100000
# 2020-12-08 06:07:00,150 epoch 26 - iter 8/44 - loss 0.45268381 - samples/sec: 126.36 - lr: 0.100000
# 2020-12-08 06:07:01,130 epoch 26 - iter 12/44 - loss 0.45820163 - samples/sec: 130.68 - lr: 0.100000
# 2020-12-08 06:07:02,294 epoch 26 - iter 16/44 - loss 0.48172382 - samples/sec: 110.06 - lr: 0.100000
# 2020-12-08 06:07:03,425 epoch 26 - iter 20/44 - loss 0.45935837 - samples/sec: 113.29 - lr: 0.100000
# 2020-12-08 06:07:04,395 epoch 26 - iter 24/44 - loss 0.43470623 - samples/sec: 132.15 - lr: 0.100000
# 2020-12-08 06:07:05,418 epoch 26 - iter 28/44 - loss 0.46312705 - samples/sec: 125.21 - lr: 0.100000
# 2020-12-08 06:07:06,495 epoch 26 - iter 32/44 - loss 0.46858493 - samples/sec: 118.98 - lr: 0.100000
# 2020-12-08 06:07:07,585 epoch 26 - iter 36/44 - loss 0.46009969 - samples/sec: 117.48 - lr: 0.100000
# 2020-12-08 06:07:08,718 epoch 26 - iter 40/44 - loss 0.45921068 - samples/sec: 113.13 - lr: 0.100000
# 2020-12-08 06:07:09,720 epoch 26 - iter 44/44 - loss 0.45481772 - samples/sec: 127.97 - lr: 0.100000
# 2020-12-08 06:07:09,721 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:07:09,721 EPOCH 26 done: loss 0.4548 - lr 0.1000000
# 2020-12-08 06:07:24,478 DEV : loss 1.2318347692489624 - score 0.8996
# Epoch    26: reducing learning rate of group 0 to 5.0000e-02.
# 2020-12-08 06:07:24,732 BAD EPOCHS (no improvement): 4
# 2020-12-08 06:07:24,733 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:07:25,911 epoch 27 - iter 4/44 - loss 0.41717421 - samples/sec: 108.91 - lr: 0.050000
# 2020-12-08 06:07:27,021 epoch 27 - iter 8/44 - loss 0.51227552 - samples/sec: 115.36 - lr: 0.050000
# 2020-12-08 06:07:28,101 epoch 27 - iter 12/44 - loss 0.43752570 - samples/sec: 118.64 - lr: 0.050000
# 2020-12-08 06:07:29,138 epoch 27 - iter 16/44 - loss 0.40364235 - samples/sec: 123.55 - lr: 0.050000
# 2020-12-08 06:07:30,125 epoch 27 - iter 20/44 - loss 0.38940355 - samples/sec: 129.81 - lr: 0.050000
# 2020-12-08 06:07:31,100 epoch 27 - iter 24/44 - loss 0.39870585 - samples/sec: 131.52 - lr: 0.050000
# 2020-12-08 06:07:32,179 epoch 27 - iter 28/44 - loss 0.39572199 - samples/sec: 118.73 - lr: 0.050000
# 2020-12-08 06:07:33,166 epoch 27 - iter 32/44 - loss 0.41473710 - samples/sec: 129.74 - lr: 0.050000
# 2020-12-08 06:07:34,179 epoch 27 - iter 36/44 - loss 0.40993692 - samples/sec: 126.45 - lr: 0.050000
# 2020-12-08 06:07:35,225 epoch 27 - iter 40/44 - loss 0.40660736 - samples/sec: 122.59 - lr: 0.050000
# 2020-12-08 06:07:36,316 epoch 27 - iter 44/44 - loss 0.40579238 - samples/sec: 117.39 - lr: 0.050000
# 2020-12-08 06:07:36,317 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:07:36,317 EPOCH 27 done: loss 0.4058 - lr 0.0500000
# 2020-12-08 06:07:51,056 DEV : loss 1.2025715112686157 - score 0.9056
# 2020-12-08 06:07:51,308 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:07:58,562 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:07:59,683 epoch 28 - iter 4/44 - loss 0.47758140 - samples/sec: 114.90 - lr: 0.050000
# ...
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:21:10,420 epoch 2 - iter 4/44 - loss 4.76197600 - samples/sec: 104.45 - lr: 0.100000
# 2020-12-08 06:21:11,533 epoch 2 - iter 8/44 - loss 4.43728226 - samples/sec: 115.04 - lr: 0.100000
# 2020-12-08 06:21:12,659 epoch 2 - iter 12/44 - loss 4.31616787 - samples/sec: 113.77 - lr: 0.100000
# 2020-12-08 06:21:13,777 epoch 2 - iter 16/44 - loss 4.39768603 - samples/sec: 114.65 - lr: 0.100000
# 2020-12-08 06:21:14,970 epoch 2 - iter 20/44 - loss 4.33788193 - samples/sec: 107.32 - lr: 0.100000
# 2020-12-08 06:21:16,145 epoch 2 - iter 24/44 - loss 4.24935501 - samples/sec: 109.07 - lr: 0.100000
# 2020-12-08 06:21:17,209 epoch 2 - iter 28/44 - loss 4.20826307 - samples/sec: 120.41 - lr: 0.100000
# 2020-12-08 06:21:18,437 epoch 2 - iter 32/44 - loss 4.14210234 - samples/sec: 104.38 - lr: 0.100000
# 2020-12-08 06:21:19,556 epoch 2 - iter 36/44 - loss 4.05924739 - samples/sec: 114.59 - lr: 0.100000
# 2020-12-08 06:21:20,677 epoch 2 - iter 40/44 - loss 4.00462846 - samples/sec: 114.32 - lr: 0.100000
# 2020-12-08 06:21:21,880 epoch 2 - iter 44/44 - loss 3.98959537 - samples/sec: 106.45 - lr: 0.100000
# 2020-12-08 06:21:21,881 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:21:21,882 EPOCH 2 done: loss 3.9896 - lr 0.1000000
# 2020-12-08 06:21:37,784 DEV : loss 2.498549222946167 - score 0.7849
# 2020-12-08 06:21:38,067 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:21:44,785 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:21:45,913 epoch 3 - iter 4/44 - loss 3.69593632 - samples/sec: 114.31 - lr: 0.100000
# 2020-12-08 06:21:46,939 epoch 3 - iter 8/44 - loss 3.52911359 - samples/sec: 124.86 - lr: 0.100000
# 2020-12-08 06:21:47,903 epoch 3 - iter 12/44 - loss 3.21325837 - samples/sec: 132.89 - lr: 0.100000
# 2020-12-08 06:21:49,029 epoch 3 - iter 16/44 - loss 3.15698609 - samples/sec: 113.86 - lr: 0.100000
# 2020-12-08 06:21:49,997 epoch 3 - iter 20/44 - loss 3.07847278 - samples/sec: 132.30 - lr: 0.100000
# 2020-12-08 06:21:51,100 epoch 3 - iter 24/44 - loss 2.98832344 - samples/sec: 116.25 - lr: 0.100000
# 2020-12-08 06:21:52,341 epoch 3 - iter 28/44 - loss 3.03290564 - samples/sec: 103.23 - lr: 0.100000
# 2020-12-08 06:21:53,473 epoch 3 - iter 32/44 - loss 2.92423218 - samples/sec: 113.15 - lr: 0.100000
# 2020-12-08 06:21:54,569 epoch 3 - iter 36/44 - loss 2.83694636 - samples/sec: 116.89 - lr: 0.100000
# 2020-12-08 06:21:55,691 epoch 3 - iter 40/44 - loss 2.87055157 - samples/sec: 114.18 - lr: 0.100000
# 2020-12-08 06:21:56,818 epoch 3 - iter 44/44 - loss 2.86007631 - samples/sec: 113.65 - lr: 0.100000
# 2020-12-08 06:21:56,819 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:21:56,819 EPOCH 3 done: loss 2.8601 - lr 0.1000000
# 2020-12-08 06:22:13,642 DEV : loss 2.0122880935668945 - score 0.8023
# 2020-12-08 06:22:13,906 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:22:20,899 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:22:21,978 epoch 4 - iter 4/44 - loss 2.03653443 - samples/sec: 119.62 - lr: 0.100000
# 2020-12-08 06:22:23,012 epoch 4 - iter 8/44 - loss 2.24533382 - samples/sec: 123.89 - lr: 0.100000
# 2020-12-08 06:22:24,114 epoch 4 - iter 12/44 - loss 2.36823386 - samples/sec: 116.26 - lr: 0.100000
# 2020-12-08 06:22:25,081 epoch 4 - iter 16/44 - loss 2.24323329 - samples/sec: 132.56 - lr: 0.100000
# 2020-12-08 06:22:26,059 epoch 4 - iter 20/44 - loss 2.16788335 - samples/sec: 131.13 - lr: 0.100000
# 2020-12-08 06:22:27,143 epoch 4 - iter 24/44 - loss 2.24778330 - samples/sec: 118.17 - lr: 0.100000
# 2020-12-08 06:22:28,231 epoch 4 - iter 28/44 - loss 2.17911710 - samples/sec: 117.70 - lr: 0.100000
# 2020-12-08 06:22:29,448 epoch 4 - iter 32/44 - loss 2.27023792 - samples/sec: 105.22 - lr: 0.100000
# 2020-12-08 06:22:30,523 epoch 4 - iter 36/44 - loss 2.28082760 - samples/sec: 119.19 - lr: 0.100000
# 2020-12-08 06:22:31,607 epoch 4 - iter 40/44 - loss 2.28107421 - samples/sec: 118.19 - lr: 0.100000
# 2020-12-08 06:22:32,765 epoch 4 - iter 44/44 - loss 2.27973337 - samples/sec: 110.66 - lr: 0.100000
# 2020-12-08 06:22:32,766 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:22:32,766 EPOCH 4 done: loss 2.2797 - lr 0.1000000
# 2020-12-08 06:22:48,299 DEV : loss 1.7720857858657837 - score 0.8215
# 2020-12-08 06:22:48,565 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:22:55,337 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:22:56,451 epoch 5 - iter 4/44 - loss 1.79262453 - samples/sec: 115.61 - lr: 0.100000
# 2020-12-08 06:22:57,442 epoch 5 - iter 8/44 - loss 1.81521191 - samples/sec: 129.26 - lr: 0.100000
# 2020-12-08 06:22:58,589 epoch 5 - iter 12/44 - loss 1.79477754 - samples/sec: 111.68 - lr: 0.100000
# 2020-12-08 06:22:59,642 epoch 5 - iter 16/44 - loss 1.78817351 - samples/sec: 121.65 - lr: 0.100000
# 2020-12-08 06:23:00,709 epoch 5 - iter 20/44 - loss 1.79807621 - samples/sec: 120.05 - lr: 0.100000
# 2020-12-08 06:23:01,839 epoch 5 - iter 24/44 - loss 1.87757376 - samples/sec: 113.37 - lr: 0.100000
# 2020-12-08 06:23:03,622 epoch 5 - iter 28/44 - loss 1.90255882 - samples/sec: 71.81 - lr: 0.100000
# 2020-12-08 06:23:04,555 epoch 5 - iter 32/44 - loss 1.86273168 - samples/sec: 137.42 - lr: 0.100000
# 2020-12-08 06:23:05,632 epoch 5 - iter 36/44 - loss 1.85510329 - samples/sec: 118.94 - lr: 0.100000
# 2020-12-08 06:23:06,691 epoch 5 - iter 40/44 - loss 1.82227502 - samples/sec: 121.01 - lr: 0.100000
# 2020-12-08 06:23:07,896 epoch 5 - iter 44/44 - loss 1.89673560 - samples/sec: 106.31 - lr: 0.100000
# 2020-12-08 06:23:07,897 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:23:07,897 EPOCH 5 done: loss 1.8967 - lr 0.1000000
# 2020-12-08 06:23:23,632 DEV : loss 1.6558209657669067 - score 0.846
# 2020-12-08 06:23:23,892 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:23:30,617 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:23:31,660 epoch 6 - iter 4/44 - loss 1.68540365 - samples/sec: 123.68 - lr: 0.100000
# 2020-12-08 06:23:32,678 epoch 6 - iter 8/44 - loss 1.72810216 - samples/sec: 125.83 - lr: 0.100000
# 2020-12-08 06:23:33,829 epoch 6 - iter 12/44 - loss 1.78737897 - samples/sec: 111.38 - lr: 0.100000
# 2020-12-08 06:23:34,903 epoch 6 - iter 16/44 - loss 1.88908667 - samples/sec: 119.23 - lr: 0.100000
# 2020-12-08 06:23:35,965 epoch 6 - iter 20/44 - loss 1.90539227 - samples/sec: 120.68 - lr: 0.100000
# 2020-12-08 06:23:37,061 epoch 6 - iter 24/44 - loss 1.84703616 - samples/sec: 116.87 - lr: 0.100000
# 2020-12-08 06:23:38,172 epoch 6 - iter 28/44 - loss 1.73429712 - samples/sec: 115.23 - lr: 0.100000
# 2020-12-08 06:23:39,261 epoch 6 - iter 32/44 - loss 1.71412341 - samples/sec: 117.75 - lr: 0.100000
# 2020-12-08 06:23:40,318 epoch 6 - iter 36/44 - loss 1.68991814 - samples/sec: 121.09 - lr: 0.100000
# 2020-12-08 06:23:41,415 epoch 6 - iter 40/44 - loss 1.69803414 - samples/sec: 116.86 - lr: 0.100000
# 2020-12-08 06:23:42,717 epoch 6 - iter 44/44 - loss 1.70494676 - samples/sec: 98.41 - lr: 0.100000
# 2020-12-08 06:23:42,718 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:23:42,720 EPOCH 6 done: loss 1.7049 - lr 0.1000000
# 2020-12-08 06:23:58,963 DEV : loss 1.5359939336776733 - score 0.8414
# 2020-12-08 06:23:59,250 BAD EPOCHS (no improvement): 1
# 2020-12-08 06:23:59,252 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:24:00,426 epoch 7 - iter 4/44 - loss 1.37260234 - samples/sec: 109.21 - lr: 0.100000
# 2020-12-08 06:24:01,547 epoch 7 - iter 8/44 - loss 1.17217671 - samples/sec: 114.35 - lr: 0.100000
# 2020-12-08 06:24:02,810 epoch 7 - iter 12/44 - loss 1.23583345 - samples/sec: 101.43 - lr: 0.100000
# 2020-12-08 06:24:03,887 epoch 7 - iter 16/44 - loss 1.21843741 - samples/sec: 119.01 - lr: 0.100000
# 2020-12-08 06:24:05,072 epoch 7 - iter 20/44 - loss 1.31189829 - samples/sec: 108.12 - lr: 0.100000
# 2020-12-08 06:24:06,436 epoch 7 - iter 24/44 - loss 1.35485588 - samples/sec: 93.87 - lr: 0.100000
# 2020-12-08 06:24:07,594 epoch 7 - iter 28/44 - loss 1.34814061 - samples/sec: 110.64 - lr: 0.100000
# 2020-12-08 06:24:08,867 epoch 7 - iter 32/44 - loss 1.48023401 - samples/sec: 100.58 - lr: 0.100000
# 2020-12-08 06:24:09,929 epoch 7 - iter 36/44 - loss 1.50688271 - samples/sec: 120.67 - lr: 0.100000
# 2020-12-08 06:24:10,945 epoch 7 - iter 40/44 - loss 1.49922044 - samples/sec: 126.18 - lr: 0.100000
# 2020-12-08 06:24:11,988 epoch 7 - iter 44/44 - loss 1.49143829 - samples/sec: 122.73 - lr: 0.100000
# 2020-12-08 06:24:11,989 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:24:11,990 EPOCH 7 done: loss 1.4914 - lr 0.1000000
# 2020-12-08 06:24:27,907 DEV : loss 1.4394904375076294 - score 0.8497
# 2020-12-08 06:24:28,164 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:24:34,841 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:24:35,918 epoch 8 - iter 4/44 - loss 1.44888660 - samples/sec: 119.83 - lr: 0.100000
# 2020-12-08 06:24:37,011 epoch 8 - iter 8/44 - loss 1.32276708 - samples/sec: 117.19 - lr: 0.100000
# 2020-12-08 06:24:38,113 epoch 8 - iter 12/44 - loss 1.27907935 - samples/sec: 116.22 - lr: 0.100000
# 2020-12-08 06:24:39,158 epoch 8 - iter 16/44 - loss 1.32395729 - samples/sec: 122.61 - lr: 0.100000
# 2020-12-08 06:24:40,300 epoch 8 - iter 20/44 - loss 1.32823351 - samples/sec: 112.20 - lr: 0.100000
# 2020-12-08 06:24:41,614 epoch 8 - iter 24/44 - loss 1.29626287 - samples/sec: 97.50 - lr: 0.100000
# 2020-12-08 06:24:42,679 epoch 8 - iter 28/44 - loss 1.35554305 - samples/sec: 120.39 - lr: 0.100000
# 2020-12-08 06:24:43,923 epoch 8 - iter 32/44 - loss 1.33896384 - samples/sec: 102.96 - lr: 0.100000
# 2020-12-08 06:24:45,236 epoch 8 - iter 36/44 - loss 1.34288376 - samples/sec: 97.54 - lr: 0.100000
# 2020-12-08 06:24:46,423 epoch 8 - iter 40/44 - loss 1.36399168 - samples/sec: 107.97 - lr: 0.100000
# 2020-12-08 06:24:47,697 epoch 8 - iter 44/44 - loss 1.34477697 - samples/sec: 100.59 - lr: 0.100000
# 2020-12-08 06:24:47,698 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:24:47,698 EPOCH 8 done: loss 1.3448 - lr 0.1000000
# 2020-12-08 06:25:03,081 DEV : loss 1.4135793447494507 - score 0.8669
# 2020-12-08 06:25:03,338 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:25:10,633 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:25:11,733 epoch 9 - iter 4/44 - loss 1.40719776 - samples/sec: 117.27 - lr: 0.100000
# 2020-12-08 06:25:12,698 epoch 9 - iter 8/44 - loss 1.20762020 - samples/sec: 132.84 - lr: 0.100000
# 2020-12-08 06:25:13,788 epoch 9 - iter 12/44 - loss 1.14184758 - samples/sec: 117.53 - lr: 0.100000
# 2020-12-08 06:25:15,030 epoch 9 - iter 16/44 - loss 1.20346684 - samples/sec: 103.14 - lr: 0.100000
# 2020-12-08 06:25:16,102 epoch 9 - iter 20/44 - loss 1.17081268 - samples/sec: 119.50 - lr: 0.100000
# 2020-12-08 06:25:17,189 epoch 9 - iter 24/44 - loss 1.18734486 - samples/sec: 117.83 - lr: 0.100000
# 2020-12-08 06:25:18,253 epoch 9 - iter 28/44 - loss 1.16947216 - samples/sec: 120.44 - lr: 0.100000
# 2020-12-08 06:25:19,416 epoch 9 - iter 32/44 - loss 1.26359576 - samples/sec: 110.08 - lr: 0.100000
# 2020-12-08 06:25:20,432 epoch 9 - iter 36/44 - loss 1.24320020 - samples/sec: 126.17 - lr: 0.100000
# 2020-12-08 06:25:21,558 epoch 9 - iter 40/44 - loss 1.22208816 - samples/sec: 113.79 - lr: 0.100000
# 2020-12-08 06:25:22,503 epoch 9 - iter 44/44 - loss 1.17197062 - samples/sec: 135.60 - lr: 0.100000
# 2020-12-08 06:25:22,504 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:25:22,504 EPOCH 9 done: loss 1.1720 - lr 0.1000000
# 2020-12-08 06:25:38,279 DEV : loss 1.3795896768569946 - score 0.8726
# 2020-12-08 06:25:38,536 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:25:45,091 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:25:46,053 epoch 10 - iter 4/44 - loss 1.29729629 - samples/sec: 134.12 - lr: 0.100000
# 2020-12-08 06:25:47,166 epoch 10 - iter 8/44 - loss 1.11533436 - samples/sec: 115.09 - lr: 0.100000
# 2020-12-08 06:25:48,244 epoch 10 - iter 12/44 - loss 1.17466462 - samples/sec: 118.84 - lr: 0.100000
# 2020-12-08 06:25:49,303 epoch 10 - iter 16/44 - loss 1.13633899 - samples/sec: 121.01 - lr: 0.100000
# 2020-12-08 06:25:50,332 epoch 10 - iter 20/44 - loss 1.09810317 - samples/sec: 124.41 - lr: 0.100000
# 2020-12-08 06:25:51,503 epoch 10 - iter 24/44 - loss 1.11346992 - samples/sec: 109.46 - lr: 0.100000
# 2020-12-08 06:25:52,640 epoch 10 - iter 28/44 - loss 1.13983293 - samples/sec: 112.67 - lr: 0.100000
# 2020-12-08 06:25:53,672 epoch 10 - iter 32/44 - loss 1.14221459 - samples/sec: 124.12 - lr: 0.100000
# 2020-12-08 06:25:54,710 epoch 10 - iter 36/44 - loss 1.11930114 - samples/sec: 123.40 - lr: 0.100000
# 2020-12-08 06:25:55,920 epoch 10 - iter 40/44 - loss 1.12249503 - samples/sec: 105.92 - lr: 0.100000
# 2020-12-08 06:25:56,950 epoch 10 - iter 44/44 - loss 1.10999042 - samples/sec: 124.29 - lr: 0.100000
# 2020-12-08 06:25:56,951 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:25:56,952 EPOCH 10 done: loss 1.1100 - lr 0.1000000
# 2020-12-08 06:26:12,341 DEV : loss 1.2927216291427612 - score 0.8762
# 2020-12-08 06:26:12,595 BAD EPOCHS (no improvement): 0
# saving best model
# 2020-12-08 06:26:20,044 ----------------------------------------------------------------------------------------------------
# train mode resetting embeddings
# train mode resetting embeddings
# 2020-12-08 06:26:21,200 epoch 11 - iter 4/44 - loss 0.85787798 - samples/sec: 111.55 - lr: 0.100000
# 2020-12-08 06:26:22,337 epoch 11 - iter 8/44 - loss 1.16362464 - samples/sec: 112.75 - lr: 0.100000
# 2020-12-08 06:26:23,498 epoch 11 - iter 12/44 - loss 1.14786091 - samples/sec: 110.36 - lr: 0.100000
# 2020-12-08 06:26:24,536 epoch 11 - iter 16/44 - loss 1.09990160 - samples/sec: 123.44 - lr: 0.100000
# 2020-12-08 06:26:25,513 epoch 11 - iter 20/44 - loss 1.05600896 - samples/sec: 131.11 - lr: 0.100000
# 2020-12-08 06:26:26,617 epoch 11 - iter 24/44 - loss 1.05610317 - samples/sec: 116.07 - lr: 0.100000
# 2020-12-08 06:26:27,756 epoch 11 - iter 28/44 - loss 1.03480220 - samples/sec: 112.50 - lr: 0.100000
# 2020-12-08 06:26:28,892 epoch 11 - iter 32/44 - loss 1.01184833 - samples/sec: 112.72 - lr: 0.100000
# 2020-12-08 06:26:29,984 epoch 11 - iter 36/44 - loss 0.99391170 - samples/sec: 117.34 - lr: 0.100000
# 2020-12-08 06:26:30,996 epoch 11 - iter 40/44 - loss 0.97997617 - samples/sec: 126.66 - lr: 0.100000
# 2020-12-08 06:26:32,091 epoch 11 - iter 44/44 - loss 0.98165445 - samples/sec: 117.05 - lr: 0.100000
# 2020-12-08 06:26:32,092 ----------------------------------------------------------------------------------------------------
# 2020-12-08 06:26:32,092 EPOCH 11 done: loss 0.9817 - lr 0.1000000
